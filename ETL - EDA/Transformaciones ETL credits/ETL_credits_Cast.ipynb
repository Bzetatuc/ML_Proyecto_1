# %%
import pandas as pd
import json

# %%
df = pd.read_csv("/Users/benjaminzelaya/Desktop/Proyecto_ML_Final/Datasets Sin Modificar/credits.csv")
df.head(3)
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602

# %%
# Obtener las columnas actuales del DataFrame
columnas_actuales = df.columns.tolist()

# Definir el nuevo orden de las columnas
nuevo_orden = ['id', 'cast', 'crew']

# Reordenar las columnas del DataFrame
df = df[nuevo_orden]

# %%
df_cast = df[['id', 'cast']]

# %%
pd.set_option('display.max_colwidth', None)

df_cast.head()
# Out:
#       id  \
# 0    862
# 1   8844
# 2  15602
# 3  31357
# 4  11862
#
# ...

# %%
df_cast.columns
# Out:
# Index(['id', 'cast'], dtype='object')

# %%
import ast 

df_cast['cast'] = df_cast['cast'].apply(ast.literal_eval)
# Out:
# /var/folders/9h/wktndydj5rg6pj7yfx6ws1gm0000gn/T/ipykernel_12081/3083832481.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cast['cast'] = df_cast['cast'].apply(ast.literal_eval)

# %%
# Desanidar columna Cast

df_exploded = df_cast.explode('cast')

def extract_cast_info(x):
    if isinstance(x, dict):
        return pd.Series([x.get('cast_id', ''), x.get('character', ''), x.get('credit_id', ''), x.get('gender', ''), x.get('id', ''), x.get('name', ''), x.get('order', ''), x.get('profile_path', '')])
    else:
        return pd.Series(['', '', '', '', '', '', '', ''])

df_exploded[['cast_id', 'character', 'credit_id', 'gender', 'id', 'name', 'order', 'profile_path']] = df_exploded['cast'].apply(extract_cast_info)

# %%
df_cast = df_cast.join(df_exploded[['cast_id', 'character', 'credit_id', 'gender', 'id', 'name', 'order', 'profile_path']], lsuffix='_df', rsuffix='_df_exploded')

# %%
print("Columnas en df_exploded:", df_exploded.columns)
# Out:
# Columnas en df_exploded: Index(['id', 'cast', 'cast_id', 'character', 'credit_id', 'gender', 'name',
#        'order', 'profile_path'],
#       dtype='object')

# %%
df_cast.head()
# Out:
#    id_df  \
# 0    862
# 0    862
# 0    862
# 0    862
# 0    862
#
# ...

# %%
df_cast.drop('cast', axis=1, inplace=True)

# %%
df_cast.columns
# Out:
# Index(['id_df', 'cast_id', 'character', 'credit_id', 'gender',
#        'id_df_exploded', 'name', 'order', 'profile_path'],
#       dtype='object')

# %%
df_cast.head()
# Out:
#    id_df cast_id                character                 credit_id gender  \
# 0    862      14            Woody (voice)  52fe4284c3a36847f8024f95      2
# 0    862      15   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99      2
# 0    862      16  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d      2
# 0    862      17       Slinky Dog (voice)  52fe4284c3a36847f8024fa1      2
# 0    862      18              Rex (voice)  52fe4284c3a36847f8024fa5      2
#
#   id_df_exploded           name order                      profile_path
# 0             31      Tom Hanks     0  /pQFoyx7rp09CJTAb932F2g8Nlho.jpg
# 0          12898      Tim Allen     1  /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg
# 0           7167    Don Rickles     2  /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg
# 0          12899     Jim Varney     3  /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg
# 0          12900  Wallace Shawn     4  /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg

# %%
df_cast = df_cast.rename(columns={'id_df_exploded': 'id'})
df_cast = df_cast.rename(columns={'id_df': 'id_peliculas'})

# %%
df_cast.head()
# Out:
#    id_peliculas cast_id                character                 credit_id  \
# 0           862      14            Woody (voice)  52fe4284c3a36847f8024f95
# 0           862      15   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99
# 0           862      16  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d
# 0           862      17       Slinky Dog (voice)  52fe4284c3a36847f8024fa1
# 0           862      18              Rex (voice)  52fe4284c3a36847f8024fa5
#
#   gender     id           name order                      profile_path
# 0      2     31      Tom Hanks     0  /pQFoyx7rp09CJTAb932F2g8Nlho.jpg
# 0      2  12898      Tim Allen     1  /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg
# 0      2   7167    Don Rickles     2  /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg
# 0      2  12899     Jim Varney     3  /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg
# 0      2  12900  Wallace Shawn     4  /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg

# %%
data_cast = df_cast

# Creo el dataframe con las columnas indicadas guardando el mismo dentro la carpeta Transformaciones credits
data_cast.to_csv("cast.csv", index=False)

# %%
data_cast.head(5)
# Out:
#    id_peliculas cast_id                character                 credit_id  \
# 0           862      14            Woody (voice)  52fe4284c3a36847f8024f95
# 0           862      15   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99
# 0           862      16  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d
# 0           862      17       Slinky Dog (voice)  52fe4284c3a36847f8024fa1
# 0           862      18              Rex (voice)  52fe4284c3a36847f8024fa5
#
#   gender     id           name order                      profile_path
# 0      2     31      Tom Hanks     0  /pQFoyx7rp09CJTAb932F2g8Nlho.jpg
# 0      2  12898      Tim Allen     1  /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg
# 0      2   7167    Don Rickles     2  /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg
# 0      2  12899     Jim Varney     3  /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg
# 0      2  12900  Wallace Shawn     4  /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg

# %%
data_cast.rename(columns={'name': 'Actor'},inplace=True)

# %%
data_cast.head(5)
# Out:
#    id_peliculas cast_id                character                 credit_id  \
# 0           862      14            Woody (voice)  52fe4284c3a36847f8024f95
# 0           862      15   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99
# 0           862      16  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d
# 0           862      17       Slinky Dog (voice)  52fe4284c3a36847f8024fa1
# 0           862      18              Rex (voice)  52fe4284c3a36847f8024fa5
#
#   gender     id          Actor order                      profile_path
# 0      2     31      Tom Hanks     0  /pQFoyx7rp09CJTAb932F2g8Nlho.jpg
# 0      2  12898      Tim Allen     1  /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg
# 0      2   7167    Don Rickles     2  /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg
# 0      2  12899     Jim Varney     3  /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg
# 0      2  12900  Wallace Shawn     4  /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg

# %%
Data_Actor = data_cast[['id_peliculas', 'Actor','character']]

# %%
Data_Actor.head()
# Out:
#    id_peliculas          Actor                character
# 0           862      Tom Hanks            Woody (voice)
# 0           862      Tim Allen   Buzz Lightyear (voice)
# 0           862    Don Rickles  Mr. Potato Head (voice)
# 0           862     Jim Varney       Slinky Dog (voice)
# 0           862  Wallace Shawn              Rex (voice)

# %%
# Agrupar por id de películas y crear una lista formateada de Actor y cast_id
data_cast_final = Data_Actor.groupby('id_peliculas').agg({'Actor': lambda x: "'" + "' '".join(x) + "'"}).reset_index()

data_cast_final
# Out:
#        id_peliculas  \
# 0                 2
# 1                 3
# 2                 5
# 3                 6
# 4                11
# ...             ...
# 45427        465044
# 45428        467731
# 45429        468343
# 45430        468707
# 45431        469172
#
# ...

# %%
# quiero obtener el nombre del actor que coincida con el id indicado TOY STORY
actors_grouped_id1 = data_cast_final[data_cast_final['id_peliculas'] == 862]['Actor'].values[0]

if actors_grouped_id1 is not None:
    actors_grouped_id1
else:
    print("No se encontraron actores para el ID 1.")

# %%
 actors_grouped_id1
# Out:
# "'Tom Hanks' 'Tim Allen' 'Don Rickles' 'Jim Varney' 'Wallace Shawn' 'John Ratzenberger' 'Annie Potts' 'John Morris' 'Erik von Detten' 'Laurie Metcalf' 'R. Lee Ermey' 'Sarah Freeman' 'Penn Jillette'"

# %%
# Agrupar por 'id_peliculas' y 'character' y agregar los actores a una lista
grouped_actors = Data_Actor.groupby(['id_peliculas', 'character'])['Actor'].apply(list).reset_index()

# Imprimir el resultado de la agrupación para el ID de película 862
id_peliculas_862 = grouped_actors[grouped_actors['id_peliculas'] == 862]
if not id_peliculas_862.empty:
    print(id_peliculas_862)
else:
    print("No se encontraron actores para el ID de película 862.")
# Out:
#        id_peliculas                character                Actor
# 16396           862             Andy (voice)        [John Morris]
# 16397           862          Bo Peep (voice)        [Annie Potts]
# 16398           862   Buzz Lightyear (voice)          [Tim Allen]
# 16399           862             Hamm (voice)  [John Ratzenberger]
# 16400           862           Hannah (voice)      [Sarah Freeman]
# 16401           862  Mr. Potato Head (voice)        [Don Rickles]
# 16402           862       Mrs. Davis (voice)     [Laurie Metcalf]
# 16403           862              Rex (voice)      [Wallace Shawn]
# 16404           862         Sergeant (voice)       [R. Lee Ermey]
# 16405           862              Sid (voice)    [Erik von Detten]
# 16406           862       Slinky Dog (voice)         [Jim Varney]
# 16407           862     TV Announcer (voice)      [Penn Jillette]
# 16408           862            Woody (voice)          [Tom Hanks]

# %%
from IPython.display import display


# Agrupar por 'id_peliculas' y 'character' y agregar los actores a una lista
grouped_actors = Data_Actor.groupby(['id_peliculas', 'character'])['Actor'].apply(list).reset_index()

# Imprimir el resultado de la agrupación para el ID de película 597 (TITANIC)
id_peliculas_597 = grouped_actors[grouped_actors['id_peliculas'] == 597]
if not id_peliculas_597.empty:
    print(id_peliculas_597)
else:
    print("No se encontraron actores para el ID de película 597.")
# Out:
#        id_peliculas                          character                   Actor
# 10580           597      1st Class Dining Room Steward   [Stephen Wolfe Smith]
# 10581           597                  1st Class Husband          [John Walcutt]
# 10582           597                      1st Class Man         [Bruno Campolo]
# 10583           597  1st Class Passenger / Praying Man        [Griffin Howell]
# 10584           597                  1st Class Steward          [Emmett James]
# ...             ...                                ...                     ...
# 10698           597                             Waiter      [George Kosty III]
# 10699           597                    Wallace Hartley  [Jonathan Evans-Jones]
# 10700           597                              Woman         [Tricia O'Neil]
# 10701           597                     Woman in Water      [Kathleen S. Dunn]
# 10702           597                              Yaley    [Mark Rafael Truitt]
#
# [123 rows x 3 columns]
