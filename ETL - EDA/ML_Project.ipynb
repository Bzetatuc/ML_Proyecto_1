# %% [markdown]
# # Inicio de Transformacion y limpieza del DataSets "movies_dataset.csv"
#
# ### Empezare importando las librerias y cargando el dataset en un dataframe para posteriormente empezar con el proceso de limpieza y transformacion <br>

# %%
# Empiezo importando las librerias que usar en el projecto

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
# creo un DataFrame en pandas(pd) a partir de los datos contenidos en movies_dataset.csv

df = pd.read_csv("/Users/benjaminzelaya/Desktop/movies_dataset.csv")

# Imprimo los primeros registros del DataFrame
df.head()
# Out:
# /var/folders/9h/wktndydj5rg6pj7yfx6ws1gm0000gn/T/ipykernel_7221/3891474210.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/benjaminzelaya/Desktop/movies_dataset.csv")
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
# Verifico que columnas tiene el dataframe y la cantidad de datos y tipo de datos en las columnas.
# tiene un total de 24 columnas.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
# Imprimo la totalidad de columnas del dataframe.
print(df.columns)
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df.shape
# Out:
# (45466, 24)

# %% [markdown]
# # Proceso de Transformacion de columnas
#
# Desanidar Columna belongs_to_collection

# %%
pd.set_option('display.max_colwidth', None)
df["belongs_to_collection"].head()
# Out:
# 0              {'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}
# 1                                                                                                                                                                NaN
# 2        {'id': 119050, 'name': 'Grumpy Old Men Collection', 'poster_path': '/nLvUdqgPgm3F85NMCii9gVFUcet.jpg', 'backdrop_path': '/hypTnLot2z8wpFS7qwsQHW1uV8u.jpg'}
# 3                                                                                                                                                                NaN
# 4    {'id': 96871, 'name': 'Father of the Bride Collection', 'poster_path': '/nts4iOmNnq7GNicycMJ9pSAn204.jpg', 'backdrop_path': '/7qwE57OVZmMJChBpLEbJEmzUydk.jpg'}
# Name: belongs_to_collection, dtype: object

# %%
df["belongs_to_collection"].info()
# verifico que la columna tan solo tiene 4494 valores no nulos , cuando el total de entradas del dataframe es de 45466.
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 45466 entries, 0 to 45465
# Series name: belongs_to_collection
# Non-Null Count  Dtype
# --------------  -----
# 4494 non-null   object
# dtypes: object(1)
# memory usage: 355.3+ KB

# %%
#creo una funcion que llamare belongs_transform donde intenta obtener el valor de una clave específica dentro de un diccionario proporcionado como argumento. 
#Si el diccionario es nulo, no es un diccionario válido o la clave no existe, la función devuelve None. 

def belongs_transform(dicc, key):
    if not isinstance(dicc, dict):
        try:
            dicc = json.loads(dicc.replace("'", "\""))
        except (json.JSONDecodeError, AttributeError):
            return None

    if isinstance(dicc, dict):
        return dicc.get(key)
    else:
        return None

# %%
# Al ejecutar la funcion creada ahora aplico la función a la columna "belongs_to_collection" de nuestro dataframe.

df['id_bellongs_to_collection'] = df['belongs_to_collection'].apply(lambda x: belongs_transform(x, 'id'))
df['name_bellongs_to_collection'] = df['belongs_to_collection'].apply(lambda x: belongs_transform(x, 'name'))
df['poster_bellongs_to_collection'] = df['belongs_to_collection'].apply(lambda x: belongs_transform(x, 'poster_path'))
df['backdrop_bellongs_to_collection'] = df['belongs_to_collection'].apply(lambda x: belongs_transform(x, 'backdrop_path'))

# %%
# Verifico los resultados obtenidos de la columna desanidada
df[['id_bellongs_to_collection', 'name_bellongs_to_collection', 'poster_bellongs_to_collection', 'backdrop_bellongs_to_collection']]
# Out:
#        id_bellongs_to_collection     name_bellongs_to_collection  \
# 0                        10194.0            Toy Story Collection
# 1                            NaN                            None
# 2                       119050.0       Grumpy Old Men Collection
# 3                            NaN                            None
# 4                        96871.0  Father of the Bride Collection
# ...                          ...                             ...
# 45461                        NaN                            None
# 45462                        NaN                            None
# 45463                        NaN                            None
# 45464                        NaN                            None
# 45465                        NaN                            None
#
#           poster_bellongs_to_collection   backdrop_bellongs_to_collection
# 0      /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# ...

# %% [markdown]
# ### Elimino la columna belongs_to_collection porque ya quedo con los valores desanidados en las nuevas columnas creadas

# %%
del df['belongs_to_collection']

# %%
df.columns
# Out:
# Index(['adult', 'budget', 'genres', 'homepage', 'id', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title', 'video', 'vote_average', 'vote_count',
#        'id_bellongs_to_collection', 'name_bellongs_to_collection',
#        'poster_bellongs_to_collection', 'backdrop_bellongs_to_collection'],
#       dtype='object')

# %% [markdown]
# ### Imprimo los primeros registros del DataFrame.
# ### Verifico las nuevas columnas de con los valores desanidados(id_bellongs_to_collection,name_bellongs_to_collection,poster_bellongs_to_collection y backdrop_bellongs_to_collection)

# %%
df.head()
# Out:
#    adult    budget  \
# 0  False  30000000
# 1  False  65000000
# 2  False         0
# 3  False  16000000
# 4  False         0
#
#                                                                                               genres  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]
# 2                                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]
# 4                                                                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# ...

# %% [markdown]
# # Proceso de Transformacion de columnas
#
# Desanidar Columna Genres

# %%
pd.set_option('display.max_colwidth', None)
df['genres'].head()
# Out:
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]
# 1    [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]
# 2                                     [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]
# 4                                                                       [{'id': 35, 'name': 'Comedy'}]
# Name: genres, dtype: object

# %%
df['genres'].isnull().mean()
# Out:
# 0.0

# %%
import ast

# los valores faltantes (NaN) vamos a convertir convirtiéndolos en una lista vacía
df['genres'] = df['genres'].fillna('[]')

# %%
# Los datos de cadena en listas de diccionarios los vamos a convertir utilizando 'eval()', ya que no puedo desanidar porque estan en string , y no en diccionarios.
import ast
df['genres'] = df['genres'].apply(ast.literal_eval)

# %%
# use  función explode que me permite  expandir la lista  en filas separadas
df_exploded = df.explode('genres', ignore_index=True)

# %%
# Extraer los nombres e ids de las compañías en columnas separadas
df_exploded['name_genres'] = df_exploded['genres'].apply(lambda x: x.get('name', '') if isinstance(x, dict) else '')
df_exploded['id_genres'] = df_exploded['genres'].apply(lambda x: x.get('id', '') if isinstance(x, dict) else '')

# %%
df = df.join(df_exploded[['name_genres', 'id_genres']])
## utilizando join uno las nuevas columnas que iran en el dataframe original

# %%
df = df.reset_index(drop=True)
#Reseteo el index del dataframe

# %%
df[['name_genres', 'id_genres']]
# Out:
#       name_genres id_genres
# 0       Animation        16
# 1          Comedy        35
# 2          Family     10751
# 3       Adventure        12
# 4         Fantasy        14
# ...           ...       ...
# 45461      Comedy        35
# 45462       Music     10402
# 45463      Comedy        35
# 45464       Drama        18
# 45465     Romance     10749
#
# [45466 rows x 2 columns]

# %%
del df['genres']

# %% [markdown]
# ### Imprimo los primeros registros del DataFrame.
# ### Verifico las nuevas columnas de con los valores desanidados(Genres_id y Genres_name)

# %%
df.head()
# Out:
#    adult    budget                              homepage     id    imdb_id  \
# 0  False  30000000  http://toystory.disney.com/toy-story    862  tt0114709
# 1  False  65000000                                   NaN   8844  tt0113497
# 2  False         0                                   NaN  15602  tt0113228
# 3  False  16000000                                   NaN  31357  tt0114885
# 4  False         0                                   NaN  11862  tt0113041
#
#   original_language               original_title  \
# 0                en                    Toy Story
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
#
# ...

# %% [markdown]
# # Proceso de Transformacion de columnas
#
# Desanidar Columna  production_companies

# %%
df['production_companies'].head()
# Out:
# 0                                                                                         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1    [{'name': 'TriStar Pictures', 'id': 559}, {'name': 'Teitler Film', 'id': 2550}, {'name': 'Interscope Communications', 'id': 10201}]
# 2                                                        [{'name': 'Warner Bros.', 'id': 6194}, {'name': 'Lancaster Gate', 'id': 19464}]
# 3                                                                        [{'name': 'Twentieth Century Fox Film Corporation', 'id': 306}]
# 4                                           [{'name': 'Sandollar Productions', 'id': 5842}, {'name': 'Touchstone Pictures', 'id': 9195}]
# Name: production_companies, dtype: object

# %%
pd.set_option('display.max_colwidth', None)
print(df['production_companies'])
# Out:
# 0                                                                                             [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1        [{'name': 'TriStar Pictures', 'id': 559}, {'name': 'Teitler Film', 'id': 2550}, {'name': 'Interscope Communications', 'id': 10201}]
# 2                                                            [{'name': 'Warner Bros.', 'id': 6194}, {'name': 'Lancaster Gate', 'id': 19464}]
# 3                                                                            [{'name': 'Twentieth Century Fox Film Corporation', 'id': 306}]
# 4                                               [{'name': 'Sandollar Productions', 'id': 5842}, {'name': 'Touchstone Pictures', 'id': 9195}]
#                                                                         ...
# 45461                                                                                                                                     []
# ...

# %%
import ast

# Los datos de cadena en listas de diccionarios los vamos a convertir utilizando 'eval()', ya que no puedo desanidar porque estan en string , y no en diccionarios.
# los valores faltantes (NaN) vamos a convertir convirtiéndolos en una lista vacía
df['production_companies'] = df['production_companies'].fillna('[]')

# %%
# Los datos de cadena en listas de diccionarios los vamos a convertir utilizando 'eval()', ya que no puedo desanidar porque estan en string , y no en diccionarios.
df['production_companies'] = df['production_companies'].apply(ast.literal_eval)

# %%
# use  función explode que me permite  expandir la lista  en filas separadas
df_exploded = df.explode('production_companies', ignore_index=True)

# %%
# Extraer los nombres e ids de las compañías en columnas separadas
df_exploded['name_companies'] = df_exploded['production_companies'].apply(lambda x: x.get('name', '') if isinstance(x, dict) else '')
df_exploded['id_companies'] = df_exploded['production_companies'].apply(lambda x: x.get('id', '') if isinstance(x, dict) else '')

# %%
# Unimos los valores desanidados  con el DataFrame original movies_data
df = df.join(df_exploded[['name_companies', 'id_companies']])

# %%
df[['name_companies', 'id_companies']].head()
# Out:
#               name_companies id_companies
# 0    Pixar Animation Studios            3
# 1           TriStar Pictures          559
# 2               Teitler Film         2550
# 3  Interscope Communications        10201
# 4               Warner Bros.         6194

# %%
del df['production_companies']

# %%
df.head()
# Out:
#    adult    budget                              homepage     id    imdb_id  \
# 0  False  30000000  http://toystory.disney.com/toy-story    862  tt0114709
# 1  False  65000000                                   NaN   8844  tt0113497
# 2  False         0                                   NaN  15602  tt0113228
# 3  False  16000000                                   NaN  31357  tt0114885
# 4  False         0                                   NaN  11862  tt0113041
#
#   original_language               original_title  \
# 0                en                    Toy Story
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
#
# ...

# %% [markdown]
# # Proceso de Transformacion de columnas
#
# Desanidar Columna  production_countries

# %%
pd.set_option('display.max_colwidth', None)
df['production_countries'].head()
# Out:
# 0    [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 1    [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 2    [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 3    [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 4    [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# Name: production_countries, dtype: object

# %%
# # los valores faltantes (NaN) vamos a convertir convirtiéndolos en una lista vacía
df['production_countries'] = df['production_countries'].fillna('[]')

# %%
# # Los datos de cadena en listas de diccionarios los vamos a convertir utilizando 'eval()', ya que no puedo desanidar porque estan en string , y no en diccionarios.
import ast

df['production_countries'] = df['production_countries'].apply(ast.literal_eval)

# %%
# # use  función explode que me permite  expandir la lista  en filas separadas
# df_exploded = df.explode('production_countries', ignore_index=True)

# %%
# Desanidar la columna production_countries y crear nuevas columnas
df_exploded = df.explode('production_countries')

def extract_country_info(x):
    if isinstance(x, dict):
        return pd.Series([x.get('iso_3166_1', ''), x.get('name', '')])
    else:
        return pd.Series(['', ''])

df_exploded[['Cod_countries', 'country_name']] = df_exploded['production_countries'].apply(extract_country_info)

# %%
# # Unimos los valores desanidados  con el DataFrame original movies_data
df = df.join(df_exploded[['Cod_countries', 'country_name']])

# %%
df[['Cod_countries', 'country_name']].head()
# Out:
#   Cod_countries              country_name
# 0            US  United States of America
# 1            US  United States of America
# 2            US  United States of America
# 3            US  United States of America
# 4            US  United States of America

# %%
del df['production_countries']

# %%
df.head(5)
# Out:
#    adult    budget                              homepage     id    imdb_id  \
# 0  False  30000000  http://toystory.disney.com/toy-story    862  tt0114709
# 1  False  65000000                                   NaN   8844  tt0113497
# 2  False         0                                   NaN  15602  tt0113228
# 3  False  16000000                                   NaN  31357  tt0114885
# 4  False         0                                   NaN  11862  tt0113041
#
#   original_language               original_title  \
# 0                en                    Toy Story
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
#
# ...

# %% [markdown]
# # Proceso de Transformacion de columnas
#
# Desanidar Columna  spoken_languages

# %%
pd.set_option('display.max_colwidth', None)
df['spoken_languages'].head()
# Out:
# 0                                             [{'iso_639_1': 'en', 'name': 'English'}]
# 1    [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'fr', 'name': 'Français'}]
# 2                                             [{'iso_639_1': 'en', 'name': 'English'}]
# 3                                             [{'iso_639_1': 'en', 'name': 'English'}]
# 4                                             [{'iso_639_1': 'en', 'name': 'English'}]
# Name: spoken_languages, dtype: object

# %%
# los valores faltantes (NaN) vamos a convertir convirtiéndolos en una lista vacía
df['spoken_languages'] = df['spoken_languages'].fillna('[]')

# %%
# Los datos de cadena en listas de diccionarios los vamos a convertir utilizando 'eval()', ya que no puedo desanidar porque estan en string , y no en diccionarios.
import ast

df['spoken_languages'] = df['spoken_languages'].apply(ast.literal_eval)

# %%
# use  función explode que me permite  expandir la lista  en filas separadas
df_exploded = df.explode('spoken_languages', ignore_index=True)

# %%
# Extraer los nombres e ids de spoken Lenguages en columnas separadas
df_exploded['Cod_languages'] = df_exploded['spoken_languages'].apply(lambda x: x.get('iso_639_1', '') if isinstance(x, dict) else '')
df_exploded['name_languages'] = df_exploded['spoken_languages'].apply(lambda x: x.get('name', '') if isinstance(x, dict) else '')

# %%
# # Unimos los valores desanidados  con el DataFrame original movies_data
df = df.join(df_exploded[['Cod_languages', 'name_languages']])

# %%
df[['Cod_languages', 'name_languages']].head()
# Out:
#   Cod_languages name_languages
# 0            en        English
# 1            en        English
# 2            fr       Français
# 3            en        English
# 4            en        English

# %%
del df['spoken_languages']

# %%
df.head()
# Out:
#    adult    budget                              homepage     id    imdb_id  \
# 0  False  30000000  http://toystory.disney.com/toy-story    862  tt0114709
# 1  False  65000000                                   NaN   8844  tt0113497
# 2  False         0                                   NaN  15602  tt0113228
# 3  False  16000000                                   NaN  31357  tt0114885
# 4  False         0                                   NaN  11862  tt0113041
#
#   original_language               original_title  \
# 0                en                    Toy Story
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
#
# ...

# %% [markdown]
# ## Los valores nulos de los campos **`revenue`**, **`budget`** deben ser rellenados por el número **`0`**.

# %%
# Verifico como son los valores de la columna Revenue

pd.set_option('display.max_colwidth', None)
df['revenue'].head()
# Out:
# 0    373554033.0
# 1    262797249.0
# 2            0.0
# 3     81452156.0
# 4     76578911.0
# Name: revenue, dtype: float64

# %%
# Rellenar los valores nulos con 0 en la columnas "revenue"
df["revenue"].fillna(0, inplace=True)

# %%
# Verifico como son los valores de la columna budget

pd.set_option('display.max_colwidth', None)
df['budget'].head()
# Out:
# 0    30000000
# 1    65000000
# 2           0
# 3    16000000
# 4           0
# Name: budget, dtype: object

# %%
# Rellenar los valores nulos con 0 en la columnas "budget"
df["budget"].fillna(0, inplace=True)

# %% [markdown]
# ## Los valores nulos del campo **`release date`** deben eliminarse.
#
# ## De haber fechas, deberán tener el formato **`AAAA-mm-dd`**, además deberán crear la columna **`release_year`** donde extraerán el año de la fecha de estreno.

# %%
df['release_date'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45461     True
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: release_date, Length: 55711, dtype: bool

# %%
# Elimino los valones nulos de la columna realse_date
df.dropna(subset=['release_date'], inplace=True)

# %%
# Verifico que los mismos fueron realmente eliminados de la columna
df['release_date'].isnull().mean()
# Out:
# 0.0

# %%
# Ahora siguiendo con lo indicado convierto la columna "release_date" en tipo datetime, utilizando pandas.
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# %%
# # creo la columna "release_year" como se indica con el formato AAAA-mm-dd , para extraer los datos de estreno de las peliculas.
df['release_year'] = df['release_date'].dt.year
df['release_year'] = df['release_year'].astype(int)


# Si falla asegurarse que se hizo la eliminacion de los valores nulos corrextamente en la linea #65

# %%
df['release_year'].head() # Verifico como quedo la columna con los años en int
# Out:
# 0    1995
# 1    1995
# 2    1995
# 3    1995
# 4    1995
# Name: release_year, dtype: int64

# %%
# verifico como quedo el dataframe con la columna agregada.
df.head()
# Out:
#    adult    budget                              homepage     id    imdb_id  \
# 0  False  30000000  http://toystory.disney.com/toy-story    862  tt0114709
# 1  False  65000000                                   NaN   8844  tt0113497
# 2  False         0                                   NaN  15602  tt0113228
# 3  False  16000000                                   NaN  31357  tt0114885
# 4  False         0                                   NaN  11862  tt0113041
#
#   original_language               original_title  \
# 0                en                    Toy Story
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
#
# ...

# %% [markdown]
# ## Crear la columna con el retorno de inversión, llamada **`return`** con los campos **`revenue`** y **`budget`**, dividiendo estas dos últimas **`revenue / budget`**, cuando no hay datos disponibles para calcularlo, deberá tomar el valor **`0`**.

# %%
print(df['budget'].dtype)
# Out:
# object

# %%
print(df['revenue'].dtype)
# Out:
# float64

# %% [markdown]
# * algunos de los valores en la columna 'revenue' o 'budget' son de tipo 'str' (cadena de texto) en lugar de números. La división solo es compatible con valores numéricos, y al intentar dividir una cadena de texto ('str') con un número ('float'). asi que realizaremos la conversion correspondiente usando pandas  a traves de .to_numeric.

# %%
df['revenue'] = pd.to_numeric(df['revenue'], errors='coerce')
df['budget'] = pd.to_numeric(df['budget'], errors='coerce')

# %%
# Ahora si puedo crear la  columna 'return' con el retorno de inversión de las pelicuals haciendo la division correspondiente.
df['return'] = df.apply(lambda row: row['revenue'] / row['budget'] if (not pd.isnull(row['revenue']) and not pd.isnull(row['budget']) and row['budget'] != 0) else 0, axis=1)

# utilizando aplly para aplicar la funcion lambda en cada una de las columnas indicadas, con la  condición que verifica si  el valor de la columna 'revenue' como el de 'budget' no son nulos.
# y a su vez  si el valor de 'budget' es diferente de cero, para evitar division en 0 si es que faltan valores, y le indico que axis 1 para obtener los valores de cada una de las filas .

# %%
df['return'].head()
# Out:
# 0    12.451801
# 1     4.043035
# 2     0.000000
# 3     5.090760
# 4     0.000000
# Name: return, dtype: float64

# %%
df.head()
# Out:
#    adult    budget                              homepage     id    imdb_id  \
# 0  False  30000000  http://toystory.disney.com/toy-story    862  tt0114709
# 1  False  65000000                                   NaN   8844  tt0113497
# 2  False         0                                   NaN  15602  tt0113228
# 3  False  16000000                                   NaN  31357  tt0114885
# 4  False         0                                   NaN  11862  tt0113041
#
#   original_language               original_title  \
# 0                en                    Toy Story
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
#
# ...

# %%
df.columns
# Out:
# Index(['adult', 'budget', 'homepage', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'revenue', 'runtime', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count', 'id_bellongs_to_collection',
#        'name_bellongs_to_collection', 'poster_bellongs_to_collection',
#        'backdrop_bellongs_to_collection', 'name_genres', 'id_genres',
#        'name_companies', 'id_companies', 'Cod_countries', 'country_name',
#        'Cod_languages', 'name_languages', 'release_year', 'return'],
#       dtype='object')

# %% [markdown]
# # Creare un data con las columnas agregadas.

# %%
 movie_data_final = df[['id', 'original_language', 'overview', 'popularity', 'release_date',
       'runtime', 'status', 'tagline', 'title', 'vote_average', 'vote_count',
       'id_bellongs_to_collection', 'name_bellongs_to_collection',
       'poster_bellongs_to_collection', 'backdrop_bellongs_to_collection',
       'Cod_languages', 'name_languages', 'name_genres', 'id_genres',
       'name_companies', 'id_companies', 'Cod_countries', 'country_name',
       'budget', 'revenue', 'release_year', 'return']]

# Creo nuevamente otro dataframe con las columnas indicadas guardando el mismo dentro la carpeta ETL/EDA del reposotorio
 movie_data_final.to_csv( "movies_data_final.csv", index=False)

# %% [markdown]
# EMPEZAMOS CON EL ETL DE DATASETS CREDITS.CSV

# %%
# creo un DataFrame en pandas(pd) a partir de los datos contenidos en movies_dataset.csv

df_credits = pd.read_csv("/Users/benjaminzelaya/Desktop/credits.csv")

# Imprimo los primeros registros del DataFrame
df_credits.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
# Verifico que columnas tiene el dataframe y la cantidad de datos y tipo de datos en las columnas.
# tiene un total de 24 columnas.
df_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
df_credits.describe()
# Out:
#                   id
# count   45476.000000
# mean   108345.997537
# std    112443.796536
# min         2.000000
# 25%     26443.250000
# 50%     60002.500000
# 75%    157302.000000
# max    469172.000000

# %%
# Imprimo la totalidad de columnas del dataframe.
print(df_credits.columns)
# Out:
# Index(['cast', 'crew', 'id'], dtype='object')

# %%
df_credits.shape
# Out:
# (45476, 3)

# %%
# Obtener las columnas actuales del DataFrame
columnas_actuales = df.columns.tolist()

# Definir el nuevo orden de las columnas
nuevo_orden = ['id', 'cast', 'crew']

# Reordenar las columnas del DataFrame
df = df[nuevo_orden]
