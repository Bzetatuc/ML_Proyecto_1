# %%
# Empiezo importando las librerias que usar en el projecto

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
# creo un DataFrame en pandas(pd) a partir de los datos contenidos en movies_dataset.csv

df = pd.read_csv("/Users/benjaminzelaya/Desktop/movies_dataset.csv")

# Imprimo los primeros registros del DataFrame
df.head()
# Out:
# /var/folders/9h/wktndydj5rg6pj7yfx6ws1gm0000gn/T/ipykernel_3961/3891474210.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/benjaminzelaya/Desktop/movies_dataset.csv")
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
# Verifico que columnas tiene el dataframe y la cantidad de datos y tipo de datos en las columnas.
# tiene un total de 24 columnas.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %% [markdown]
# ### Eliminar las columnas que no serán utilizadas, **`video`**,**`imdb_id`**,**`adult`**,**`original_title`**,**`poster_path`** y **`homepage`**.

# %%
# Elimino las columnas indicadas ańadiendo tambien las columnas que estaban anidadas y fueron desanidadas, y suma otras mas ya que despues hare una concatenacion con esas columnas que fueron desanidadas
columnas_eliminadas = ['video', 'imdb_id', 'adult', 'original_title', 'poster_path','homepage','budget','revenue','belongs_to_collection','genres','production_companies','production_countries','spoken_languages']
df.drop(columns=columnas_eliminadas, inplace=True)

# %%
df.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['id', 'original_language', 'overview', 'popularity', 'release_date',
#        'runtime', 'status', 'tagline', 'title', 'vote_average', 'vote_count'],
#       dtype='object')>

# %%
df.head()
# Out:
#       id original_language                                           overview  \
# 0    862                en  Led by Woody, Andy's toys live happily in his ...
# 1   8844                en  When siblings Judy and Peter discover an encha...
# 2  15602                en  A family wedding reignites the ancient feud be...
# 3  31357                en  Cheated on, mistreated and stepped on, the wom...
# 4  11862                en  Just when George Banks has recovered from his ...
#
#   popularity release_date  runtime    status  \
# 0  21.946943   1995-10-30     81.0  Released
# 1  17.015539   1995-12-15    104.0  Released
# 2    11.7129   1995-12-22    101.0  Released
# 3   3.859495   1995-12-22    127.0  Released
# 4   8.387519   1995-02-10    106.0  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# ...

# %% [markdown]
# ## Empezamos a armar el dataset que utilizaremos en Machine Learning para desarrollar nuestra Analisis Exploratorio de datos.

# %%
# creo un DataFrame en pandas(pd) a partir de los datos contenidos en los dataframes que fueron reestructurados con las tranformaciones correspondientes.

df_bellongs = pd.read_csv("/Users/benjaminzelaya/Desktop/carpeta/Proyecto_ML_Individual/ETL - EDA/datasets reestructurados para empezar ETL/Data Modificados Final/bellongs_to_collections_modificado .csv")
df_m_details = pd.read_csv("/Users/benjaminzelaya/Desktop/carpeta/Proyecto_ML_Individual/ETL - EDA/datasets reestructurados para empezar ETL/Data Modificados Final/m_details_modificado.csv")
df_m_genres = pd.read_csv("/Users/benjaminzelaya/Desktop/carpeta/Proyecto_ML_Individual/ETL - EDA/datasets reestructurados para empezar ETL/Data Modificados Final/m_genres_modificado .csv")
df_productions = pd.read_csv("/Users/benjaminzelaya/Desktop/carpeta/Proyecto_ML_Individual/ETL - EDA/datasets reestructurados para empezar ETL/Data Modificados Final/m_productions_modificado.csv")
df_Languages= pd.read_csv("/Users/benjaminzelaya/Desktop/carpeta/Proyecto_ML_Individual/ETL - EDA/datasets reestructurados para empezar ETL/Data Modificados Final/m_languages_modificado.csv")

# %%
df_bellongs.head() # veo unos de los dataframe modificados para verificar si se hizo el load correctamente.
# Out:
#    id_bellongs_to_collection     name_bellongs_to_collection  \
# 0                    10194.0            Toy Story Collection
# 1                        NaN                             NaN
# 2                   119050.0       Grumpy Old Men Collection
# 3                        NaN                             NaN
# 4                    96871.0  Father of the Bride Collection
#
#       poster_bellongs_to_collection   backdrop_bellongs_to_collection
# 0  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1                               NaN                               NaN
# 2  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# 3                               NaN                               NaN
# 4  /nts4iOmNnq7GNicycMJ9pSAn204.jpg  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg

# %%
df_m_details.head() # veo unos de los dataframe modificados para verificar si se hizo el load correctamente.
# Out:
#      budget      revenue  release_year     return
# 0  30000000  373554033.0          1995  12.451801
# 1  65000000  262797249.0          1995   4.043035
# 2         0          0.0          1995   0.000000
# 3  16000000   81452156.0          1995   5.090760
# 4         0   76578911.0          1995   0.000000

# %%
df_m_genres.head() # veo unos de los dataframe modificados para verificar si se hizo el load correctamente.
# Out:
#   name_genres  id_genres
# 0   Animation       16.0
# 1      Comedy       35.0
# 2      Family    10751.0
# 3   Adventure       12.0
# 4     Fantasy       14.0

# %%
df_productions.head() # veo unos de los dataframe modificados para verificar si se hizo el load correctamente.
# Out:
#               name_companies  id_companies Cod_countries  \
# 0    Pixar Animation Studios           3.0            US
# 1           TriStar Pictures         559.0            US
# 2               Teitler Film        2550.0            US
# 3  Interscope Communications       10201.0            US
# 4               Warner Bros.        6194.0            US
#
#                country_name
# 0  United States of America
# 1  United States of America
# 2  United States of America
# 3  United States of America
# 4  United States of America

# %%
df_Languages.head() # veo unos de los dataframe modificados para verificar si se hizo el load correctamente.
# Out:
#   Cod_languages name_languages
# 0            en        English
# 1            en        English
# 2            fr       Français
# 3            en        English
# 4            en        English

# %% [markdown]
# * Utilizaremos concat de pandas para unir todas las columnas creadas a lo que sera el dataframe para nuestro EDA y Machine Learning.

# %%
dataframes_reestructurados = [df,df_bellongs,df_Languages,df_m_genres,df_productions,df_m_details]
df_Final_Final = pd.concat(dataframes_reestructurados, axis=1)

# %%
df_Final_Final.head()
# Out:
#       id original_language                                           overview  \
# 0    862                en  Led by Woody, Andy's toys live happily in his ...
# 1   8844                en  When siblings Judy and Peter discover an encha...
# 2  15602                en  A family wedding reignites the ancient feud be...
# 3  31357                en  Cheated on, mistreated and stepped on, the wom...
# 4  11862                en  Just when George Banks has recovered from his ...
#
#   popularity release_date  runtime    status  \
# 0  21.946943   1995-10-30     81.0  Released
# 1  17.015539   1995-12-15    104.0  Released
# 2    11.7129   1995-12-22    101.0  Released
# 3   3.859495   1995-12-22    127.0  Released
# 4   8.387519   1995-02-10    106.0  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# ...

# %%
df_Final_Final.columns
# Out:
# Index(['id', 'original_language', 'overview', 'popularity', 'release_date',
#        'runtime', 'status', 'tagline', 'title', 'vote_average', 'vote_count',
#        'id_bellongs_to_collection', 'name_bellongs_to_collection',
#        'poster_bellongs_to_collection', 'backdrop_bellongs_to_collection',
#        'Cod_languages', 'name_languages', 'name_genres', 'id_genres',
#        'name_companies', 'id_companies', 'Cod_countries', 'country_name',
#        'budget', 'revenue', 'release_year', 'return'],
#       dtype='object')

# %%
# Ordena el DataFrame por la columna 'revenue' en orden descendente
df_sorted = df_Final_Final.sort_values(by='revenue', ascending=False)
df_sorted
# Out:
#            id original_language  \
# 14545  272772                en
# 26525   87514                en
# 1637    10217                en
# 17807   87063                pt
# 25054  159121                fr
# ...       ...               ...
# 55706     NaN               NaN
# 55707     NaN               NaN
# 55708     NaN               NaN
# 55709     NaN               NaN
# 55710     NaN               NaN
#
#                                                 overview popularity  \
# 14545  Comedy - This DocuDramedy follows a young arti...    0.00353
# 26525  A crazed Vietnam vet bomber hijacks a Boeing 7...    2.70306
# 1637   A small mountain community in Canada is devast...   6.002992
# 17807  With the intimate feel of a documentary and th...   0.677205
# 25054  Paulette lives alone in a housing project in t...   6.031147
# ...                                                  ...        ...
# 55706                                                NaN        NaN
# ...

# %%
df_Final_Final.dropna(subset=['release_year'], inplace=True)

# %%
df_Final['release_year'] = df_Final['release_year'].astype(int) 
# modifico la columna a int

# %%
df_Final.columns
# Out:
# Index(['id', 'original_language', 'overview', 'popularity', 'release_date',
#        'runtime', 'status', 'tagline', 'title', 'vote_average', 'vote_count',
#        'id_bellongs_to_collection', 'name_bellongs_to_collection',
#        'Cod_languages', 'name_languages', 'name_genres', 'id_genres',
#        'name_companies', 'id_companies', 'Cod_countries', 'country_name',
#        'budget', 'revenue', 'release_year', 'return'],
#       dtype='object')

# %%
df_Final.head()
# Out:
#       id original_language                                           overview  \
# 0    862                en  Led by Woody, Andy's toys live happily in his ...
# 1   8844                en  When siblings Judy and Peter discover an encha...
# 2  15602                en  A family wedding reignites the ancient feud be...
# 3  31357                en  Cheated on, mistreated and stepped on, the wom...
# 4  11862                en  Just when George Banks has recovered from his ...
#
#   popularity release_date  runtime    status  \
# 0  21.946943   1995-10-30     81.0  Released
# 1  17.015539   1995-12-15    104.0  Released
# 2    11.7129   1995-12-22    101.0  Released
# 3   3.859495   1995-12-22    127.0  Released
# 4   8.387519   1995-02-10    106.0  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# ...

# %%
# Identifica las columnas duplicadas
duplicados = df_Final.columns.duplicated()

# Muestra las columnas duplicadas
print(df_Final.columns[duplicados])

# Elimina todas las columnas duplicadas excepto una
df_Final = df_Final.loc[:, ~duplicados]

# Verifica la información del DataFrame para asegurarte de que las columnas se hayan eliminado
print(df_Final.info())
# Out:
# Index(['budget', 'popularity', 'overview'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 45376 entries, 0 to 45375
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           45376 non-null  object
#  1   title                        45370 non-null  object
#  2   overview                     44426 non-null  object
#  3   popularity                   45371 non-null  object
#  4   vote_average                 45370 non-null  float64
#  5   vote_count                   45370 non-null  float64
#  6   status                       45290 non-null  object
#  7   original_language            45365 non-null  object
#  8   runtime                      45115 non-null  float64
#  9   budget                       45376 non-null  float64
#  10  revenue                      45376 non-null  float64
# ...

# %%
df_Final.columns
# Out:
# Index(['id', 'title', 'overview', 'popularity', 'vote_average', 'vote_count',
#        'status', 'original_language', 'runtime', 'budget', 'revenue',
#        'tagline', 'name_genres', 'name_bellongs_to_collection',
#        'id_bellongs_to_collection', 'name_companies', 'name_languages',
#        'budget', 'popularity', 'release_date', 'overview', 'release_year',
#        'return'],
#       dtype='object')

# %%
# Ordena el DataFrame por la columna 'revenue' en orden descendente
df_sorted = df_Final.sort_values(by='budget', ascending=False)
df_sorted
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/9h/wktndydj5rg6pj7yfx6ws1gm0000gn/T/ipykernel_3867/3677221661.py in ?()
#       1 # Ordena el DataFrame por la columna 'revenue' en orden descendente
# ----> 2 df_sorted = df_Final.sort_values(by='budget', ascending=False)
#       3 df_sorted
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6754         elif len(by):
#    6755             # len(by) == 1
#    6756
#    6757             by = by[0]
# -> 6758             k = self._get_label_or_level_values(by, axis=axis)
#    6759
#    6760             # need to rewrap column in Series to apply key function
#    6761             if key is not None:
#
# ...

# %%
pd.set_option('display.max_columns', None)
df_Final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45376 entries, 0 to 45375
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           45376 non-null  object
#  1   title                        45370 non-null  object
#  2   overview                     44426 non-null  object
#  3   popularity                   45371 non-null  object
#  4   vote_average                 45370 non-null  float64
#  5   vote_count                   45370 non-null  float64
#  6   status                       45290 non-null  object
#  7   original_language            45365 non-null  object
#  8   runtime                      45115 non-null  float64
#  9   budget                       45376 non-null  float64
#  10  revenue                      45376 non-null  float64
#  11  tagline                      20391 non-null  object
#  12  name_genres                  44906 non-null  object
# ...

# %%
df_Final = df_Final[
    [
        'id', 'title', 'overview', 'popularity', 'vote_average', 'vote_count', 'status',
        'original_language', 'runtime', 'budget', 'revenue', 'tagline',
        'name_genres', 'name_bellongs_to_collection','id_bellongs_to_collection',
        'name_companies', 'name_languages', 'budget', 'popularity', 'release_date', 'overview', 'release_year', 'return'
    ]
]

print(df_Final)
# Out:
#            id                                  title  \
# 0         862                              Toy Story
# 1        8844                                Jumanji
# 2       15602                       Grumpier Old Men
# 3       31357                      Waiting to Exhale
# 4       11862            Father of the Bride Part II
# ...       ...                                    ...
# 45371  460135  LEGO DC Super Hero Girls: Brain Drain
# 45372   42247                       Treasure Raiders
# 45373  426272                                Take Me
# 45374  408624                    A Death in the Gunj
# 45375  413421                              Phillauri
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# ...

# %%
movie_data = df_Final

movie_data.to_csv("dataset_final.csv", index=True)
