# %%
import pandas as pd
import numpy as np

# %%
datasets_df = pd.read_csv('/Users/benjaminzelaya/Desktop/ML_Proyecto_Individual_Henry/DEF API/movies_data_final.csv')
crew_df = pd.read_csv('/Users/benjaminzelaya/Desktop/ML_Proyecto_Individual_Henry/DEF API/crew.csv')
cast_df = pd.read_csv('/Users/benjaminzelaya/Desktop/ML_Proyecto_Individual_Henry/DEF API/cast.csv')
movie_genres_df = pd.read_csv('/Users/benjaminzelaya/Desktop/ML_Proyecto_Individual_Henry/DEF API/genres_groupby.csv')
ML_data = pd.read_csv('/Users/benjaminzelaya/Desktop/ML_Proyecto_Individual_Henry/DEF API/ML_data.csv')

# %%
datasets_df.columns
# Out:
# Index(['id', 'original_language', 'overview', 'popularity', 'release_date',
#        'runtime', 'status', 'tagline', 'title', 'vote_average', 'vote_count',
#        'id_bellongs_to_collection', 'name_bellongs_to_collection',
#        'poster_bellongs_to_collection', 'backdrop_bellongs_to_collection',
#        'Cod_languages', 'name_languages', 'name_genres', 'id_genres',
#        'name_companies', 'id_companies', 'Cod_countries', 'country_name',
#        'budget', 'revenue', 'release_year', 'return'],
#       dtype='object')

# %%
# Armo el data que usare para la Def:

df_Prod_exitosas = pd.DataFrame(datasets_df, columns=['id', 'title','name_companies','revenue'])

# %%
df_Prod_exitosas.head(10)
# Out:
#       id                        title                          name_companies  \
# 0    862                    Toy Story                 Pixar Animation Studios
# 1   8844                      Jumanji                        TriStar Pictures
# 2  15602             Grumpier Old Men                            Teitler Film
# 3  31357            Waiting to Exhale               Interscope Communications
# 4  11862  Father of the Bride Part II                            Warner Bros.
# 5    949                         Heat                          Lancaster Gate
# 6  11860                      Sabrina  Twentieth Century Fox Film Corporation
# 7  11860                      Sabrina  Twentieth Century Fox Film Corporation
# 8  45325                 Tom and Huck                   Sandollar Productions
# 9   9091                 Sudden Death                     Touchstone Pictures
#
#        revenue
# 0  373554033.0
# 1  262797249.0
# 2          0.0
# 3   81452156.0
# 4   76578911.0
# ...

# %%
# modifico la columna revenue para tener integer

# Convertir la columna "revenue" a valores numéricos, incluyendo los valores no finitos
df_Prod_exitosas['revenue'] = pd.to_numeric(df_Prod_exitosas['revenue'], errors='coerce')

# Convertir la columna "revenue" a tipo entero
df_Prod_exitosas['revenue'] = df_Prod_exitosas['revenue'].astype(int)

# %%
df_Prod_exitosas.head(10)
# Out:
#       id                        title                          name_companies  \
# 0    862                    Toy Story                 Pixar Animation Studios
# 1   8844                      Jumanji                        TriStar Pictures
# 2  15602             Grumpier Old Men                            Teitler Film
# 3  31357            Waiting to Exhale               Interscope Communications
# 4  11862  Father of the Bride Part II                            Warner Bros.
# 5    949                         Heat                          Lancaster Gate
# 6  11860                      Sabrina  Twentieth Century Fox Film Corporation
# 7  11860                      Sabrina  Twentieth Century Fox Film Corporation
# 8  45325                 Tom and Huck                   Sandollar Productions
# 9   9091                 Sudden Death                     Touchstone Pictures
#
#      revenue
# 0  373554033
# 1  262797249
# 2          0
# 3   81452156
# 4   76578911
# 5  187436818
# ...

# %%
# vi que tengo duplicadas asi que modificare el data
df_Prod_exitosas = df_Prod_exitosas.drop_duplicates(subset=['name_companies'], keep='first')

# %%
df_Prod_exitosas.head(10)
# Out:
#        id                        title  \
# 0     862                    Toy Story
# 1    8844                      Jumanji
# 2   15602             Grumpier Old Men
# 3   31357            Waiting to Exhale
# 4   11862  Father of the Bride Part II
# 5     949                         Heat
# 6   11860                      Sabrina
# 8   45325                 Tom and Huck
# 9    9091                 Sudden Death
# 10    710                    GoldenEye
#
#                             name_companies    revenue
# 0                  Pixar Animation Studios  373554033
# 1                         TriStar Pictures  262797249
# 2                             Teitler Film          0
# 3                Interscope Communications   81452156
# 4                             Warner Bros.   76578911
# 5                           Lancaster Gate  187436818
# 6   Twentieth Century Fox Film Corporation          0
# 8                    Sandollar Productions          0
# ...

# %%
# Guardar el DataFrame en un archivo CSV
productoras_exitosas = 'df_prod_exitosas_Def.csv'
df_Prod_exitosas.to_csv(productoras_exitosas, index=False)

print(f"El DataFrame ha sido guardado en el archivo '{productoras_exitosas}'")
# Out:
# El DataFrame ha sido guardado en el archivo 'df_prod_exitosas_Def.csv'

# %%
import locale
#módulo locale en Python proporciona funciones para realizar operaciones de formato y manipulación de datos basadas en las configuraciones locales del sistema operativo.


# Configurar el locale para el formato de moneda en dólares
locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')
# Out:
# 'en_US.UTF-8'

# %%
import locale

def productoras_exitosas(Productora: str):
    productora_lower = Productora.lower()

    # Rellenar los valores faltantes (NaN) en la columna 'name_companies' con una cadena vacía ('')
    df_Prod_exitosas['name_companies'] = df_Prod_exitosas['name_companies'].fillna('')

    # Filas correspondientes a la productora
    peliculas_productora = df_Prod_exitosas[df_Prod_exitosas['name_companies'].str.lower().str.contains(productora_lower)]

    # Total de revenue
    total_revenue = peliculas_productora['revenue'].sum()

    # Cantidad de películas realizadas por la productora
    cantidad_peliculas = len(peliculas_productora)

    # Formatear el revenue como moneda en dólares
    revenue_formateado = locale.currency(total_revenue, grouping=True)

    Resultado = f"La productora {Productora} ha tenido un revenue de u$s {revenue_formateado} y ha realizado {cantidad_peliculas} películas"
    return Resultado

# %%
# Productoras

df_Prod_exitosas['name_companies'].unique().tolist()
# Out:
# ['Pixar Animation Studios',
#  'TriStar Pictures',
#  'Teitler Film',
#  'Interscope Communications',
#  'Warner Bros.',
#  'Lancaster Gate',
#  'Twentieth Century Fox Film Corporation',
#  'Sandollar Productions',
#  'Touchstone Pictures',
#  'Regency Enterprises',
#  'Forward Pass',
#  'Paramount Pictures',
#  'Scott Rudin Productions',
#  'Mirage Enterprises',
#  'Constellation Entertainment',
#  'Worldwide',
#  'Mont Blanc Entertainment GmbH',
#  'Walt Disney Pictures',
#  'Universal Pictures',
#  'Imperial Entertainment',
#  'Signature Entertainment',
#  'United Artists',
#  'Eon Productions',
#  'Columbia Pictures',
#  'Castle Rock Entertainment',
#  'Enigma Pictures',
#  'Amblin Entertainment',
#  'Amblimation',
#  'Hollywood Pictures',
#  'Cinergi Pictures Entertainment',
#  'Le Studio Canal+',
#  'Laurence Mark Productions',
#  'Metro-Goldwyn-Mayer (MGM)',
#  'Carolco Pictures',
#  'Légende Entreprises',
#  'Syalis DA',
#  'De Fina-Cappa',
# ...

# %%
# EJEMPLO DE USO DE LA DEF

productora_nombre = 'Universal Pictures'
resultado = productoras_exitosas(productora_nombre)
print(resultado)
# Out:
# La productora Universal Pictures ha tenido un revenue de u$s $115,806,930.00 y ha realizado 9 películas

# %%
# EJEMPLO DE USO DE LA DEF

productora_nombre = 'Paramount Pictures'
resultado = productoras_exitosas(productora_nombre)
print(resultado)
# Out:
# La productora Paramount Pictures ha tenido un revenue de u$s $12,710,627.00 y ha realizado 4 películas
